# %%
from IPython.display import Image

# %% [markdown]
# # Data Incubator Project: Chicago Bike Sharing System
#
# ## Previous studies:
#
# ### https://citirhythms.herokuapp.com/
#
# ### https://predictbikenyc.herokuapp.com/
#
# ## Still doing exploratory analysis to find some new direction

# %% [markdown]
# ## 1. Bike flow pattern near the train station in rush hour

# %%
Image(filename="/home/chenyu/TDI/capstone/wd_am_us.png")

# %%
Image(filename="/home/chenyu/TDI/capstone/wd_pm_us.png")

# %% [markdown]
# ## 2. Supply vs. Demand

# %%
Image(filename="/home/chenyu/TDI/capstone/hist_daily_us_trips.png")

# %% [markdown]
# ### Metra data shows the daily ridership in rush hour is about 100,000
#
# ### (1) Probability that work place is within reasonable distance for biking?
#
# ### (2) Probability that people would like to bike to work?

# %% [markdown]
# ## 3. Estimate trip time
#
# ### (1) Subscribers vs. customers
#
# ### (2) Weekday rush hour trips vs. weekend trips

# %%
Image(filename="/home/chenyu/TDI/capstone/hist_tripduration_wd_we.png")
